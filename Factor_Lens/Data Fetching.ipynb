# %%
# %pip install ccxt pandas beautifulsoup4 python-dateutil requests --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import ccxt, pandas as pd
from bs4 import BeautifulSoup

print("ccxt:", ccxt.__version__)
print("pandas:", pd.__version__)
print("BeautifulSoup4 OK")
# Out:
# ccxt: 4.5.6
# pandas: 2.1.1
# BeautifulSoup4 OK

# %%
import re, time, logging, requests
from datetime import datetime, timezone, timedelta
from typing import List, Dict, Tuple, Optional
import pandas as pd
from bs4 import BeautifulSoup
from dateutil.relativedelta import relativedelta
import ccxt

LOG = logging.getLogger("top200nb")
if not LOG.handlers:
    logging.basicConfig(level=logging.INFO, format="%(asctime)s %(levelname)s %(message)s")

UA = "Mozilla/5.0"
CMC_HISTORICAL_ROOT = "https://coinmarketcap.com/historical"

# a few symbol normalizations that bite historically
SYMBOL_NORMALIZE = {
    "MATIC": "POL",
    "MIOTA": "IOTA",
    "BTTOLD": "BTT",
    "BCC": "BCH",         # ancient CMC/Binance alias
    "XBT": "BTC",
}

def month_bounds_utc(now_utc: datetime, months_back: int) -> List[Tuple[datetime, datetime]]:
    first = now_utc.replace(day=1, hour=0, minute=0, second=0, microsecond=0)
    out=[]
    for i in range(months_back):
        start = first - relativedelta(months=i)
        end   = start + relativedelta(months=1)
        out.append((start, end))
    return list(reversed(out))

def first_cmc_snapshot_on_or_after(d: datetime) -> datetime:
    wd = d.weekday()                 # Mon=0 … Sun=6
    offset = (6 - wd) % 7
    return (d + timedelta(days=offset)).replace(hour=0, minute=0, second=0, microsecond=0, tzinfo=timezone.utc)

def _flatten_cols(cols) -> list:
    # Handle MultiIndex or odd headers from read_html
    if isinstance(cols, pd.MultiIndex):
        flat = [" ".join([str(x) for x in tup if str(x) != "nan"]).strip() for tup in cols.tolist()]
    else:
        flat = [str(c).strip() for c in cols]
    return [c.lower() for c in flat]

def _parse_snapshot_table(soup: BeautifulSoup, limit=200) -> List[Dict]:
    """Try pandas.read_html first, with robust header matching."""
    tbl = soup.find("table")
    if not tbl:
        return []
    # read_html can return multiple dfs; pick the widest
    dfs = pd.read_html(str(tbl))
    if not dfs:
        return []
    df = max(dfs, key=lambda d: d.shape[1])
    cols = _flatten_cols(df.columns)
    # find candidate column indices
    def find_col(needle_opts):
        for i, c in enumerate(cols):
            for n in needle_opts:
                if n in c:
                    return i
        return None
    i_sym  = find_col(["symbol"])
    i_name = find_col(["name"])
    i_rank = find_col(["rank", "#"])
    if i_sym is None:
        return []
    take = df.iloc[:limit, :]
    rows=[]
    for idx, row in take.iterrows():
        try:
            sym = str(row.iloc[i_sym]).upper().strip()
            if not re.fullmatch(r"[A-Z0-9.\-]{2,10}", sym):
                continue
            name = str(row.iloc[i_name]).strip() if i_name is not None else ""
            rank = int(row.iloc[i_rank]) if (i_rank is not None and pd.notnull(row.iloc[i_rank])) else (idx+1)
            rows.append({"rank": rank, "name": name, "symbol": sym})
        except Exception:
            continue
    return rows

def _parse_snapshot_fallback(html: str, limit=200) -> List[Dict]:
    """
    Fallback parser: scan HTML for “coin cards”/anchors and extract SYMBOL heuristically.
    Works because snapshots render server-side with symbol tokens repeated near rank rows.
    """
    # common pattern: >BTC</a> or >BTC< within short spans; avoid long alphanum chains
    candidates = re.findall(r">([A-Z0-9]{2,10})<", html)
    # prune obvious non-symbols
    bad = {"USD","US","CMC","ETCETERA"}
    out=[]
    seen=set()
    for tok in candidates:
        if tok in bad: continue
        if not re.fullmatch(r"[A-Z0-9.\-]{2,10}", tok): continue
        if tok in seen: continue
        seen.add(tok)
        out.append(tok)
        if len(out) >= limit:
            break
    return [{"rank": i+1, "name": "", "symbol": s} for i, s in enumerate(out)]

# --- drop-in replacement for fetch_cmc_top_symbols (adds pagination) ---

def fetch_cmc_top_symbols(snapshot_date: datetime, limit=300, timeout=20) -> List[Dict]:
    """
    Scrape the CoinMarketCap 'Historical Snapshot' for `snapshot_date` (UTC),
    following pagination via ?start=1,101,201,... until `limit` symbols collected.
    Returns: list of dicts [{rank, name, symbol, snapshot_date}, ...]
    """
    ymd = snapshot_date.strftime("%Y%m%d")
    base = f"{CMC_HISTORICAL_ROOT}/{ymd}/"
    headers = {"User-Agent": UA}
    page_size = 100  # snapshots render 100 per page
    results: List[Dict] = []
    seen = set()

    for start_idx in range(1, limit + 1, page_size):
        url = f"{base}?start={start_idx}"
        LOG.info("CMC snapshot page %s  start=%d  %s", snapshot_date.date().isoformat(), start_idx, url)

        # request with a tiny retry
        ok = False
        for _ in range(3):
            try:
                r = requests.get(url, headers=headers, timeout=timeout)
                r.raise_for_status()
                html = r.text
                soup = BeautifulSoup(html, "html.parser")
                ok = True
                break
            except Exception as e:
                LOG.warning("retrying CMC page start=%d due to %s", start_idx, e)
                time.sleep(1.0)
        if not ok:
            break

        # try table parser, fallback to heuristic
        rows = _parse_snapshot_table(soup, limit=page_size)
        if not rows:
            LOG.warning("table parse failed; using fallback heuristic for start=%d", start_idx)
            syms = _parse_snapshot_fallback(html, limit=page_size)
            # normalize structure
            rows = [{"rank": None, "name": "", "symbol": r["symbol"]} for r in syms]

        # stitch into global list, assign proper rank = start_idx + position
        added = 0
        for j, row in enumerate(rows):
            sym = row["symbol"].upper().strip()
            if sym in seen:
                continue
            seen.add(sym)
            rank = start_idx + j
            results.append({
                "rank": rank,
                "name": row.get("name", ""),
                "symbol": sym,
                "snapshot_date": snapshot_date.date().isoformat(),
            })
            added += 1
            if len(results) >= limit:
                break

        LOG.info("collected so far: %d (added %d from this page)", len(results), added)
        if added == 0:  # page empty/blocked
            break
        if len(results) >= limit:
            break

    return results[:limit]


def build_exchange(venue="binance"):
    if venue not in ("binance","binanceusdm"):
        raise ValueError("venue must be binance|binanceusdm")
    ex = getattr(ccxt, venue)({"enableRateLimit": True, "options": {"adjustForTimeDifference": True}})
    ex.load_markets()
    return ex

def pick_market_symbol(ex, base_symbol, venue, quote="USDT") -> Optional[str]:
    bsym = SYMBOL_NORMALIZE.get(base_symbol, base_symbol).upper()
    if venue == "binance":
        cands = [f"{bsym}/{quote}"]
    else:
        cands = [f"{bsym}/{quote}:USDT", f"{bsym}/{quote}"]
    for s in cands:
        m = ex.markets.get(s)
        if not m: continue
        if venue == "binance" and m.get("spot"): return s
        if venue == "binanceusdm" and (m.get("swap") or m.get("contract")): return s
    # fallback: scan by base & quote
    for m in ex.markets.values():
        if m.get("base") == bsym:
            if venue == "binance" and m.get("spot") and m.get("quote") == quote:
                return m["symbol"]
            if venue == "binanceusdm" and (m.get("swap") or m.get("contract")) and quote in m["symbol"]:
                return m["symbol"]
    return None

def fetch_ohlcv_month(ex, symbol, start: datetime, end: datetime, timeframe="1d"):
    start_ms = int(start.timestamp()*1000)
    end_ms   = int(end.timestamp()*1000) - 1
    out=[]
    cursor = start_ms
    while True:
        params={}
        if ex.id in ("binance","binanceusdm"):
            params["endTime"] = end_ms
        chunk = ex.fetch_ohlcv(symbol, timeframe=timeframe, since=cursor, limit=1500, params=params)
        if not chunk: break
        out.extend(chunk)
        last_ts = chunk[-1][0]
        if last_ts >= end_ms: break
        cursor = last_ts + 60_000
        time.sleep(ex.rateLimit/1000)
    # strict filter to [start, end)
    out = [row for row in out if start_ms <= row[0] <= end_ms]
    return out



def fetch_top200_months(months=12, venue="binance", quote="USDT", limit=200, verbose=True):
    now = datetime.now(timezone.utc)
    bounds = month_bounds_utc(now, months)
    ex = build_exchange(venue)
    results = {}
    top_lists = {}
    for (mstart, mend) in bounds:
        yyyymm = mstart.strftime("%Y-%m")
        snap = first_cmc_snapshot_on_or_after(mstart)
        top = fetch_cmc_top_symbols(snap, limit=limit)
        top_df = pd.DataFrame(top)
        top_lists[yyyymm] = top_df
        if verbose:
            LOG.info("[%s] ranked symbols=%d", yyyymm, len(top_df))
        mapped=[]
        for row in top:
            sym = row["symbol"].upper()
            msym = pick_market_symbol(ex, sym, venue, quote=quote)
            if msym:
                mapped.append({**row, "exchange_symbol": msym})
        if verbose:
            LOG.info("[%s] tradable on %s: %d", yyyymm, ex.id, len(mapped))
        recs=[]
        for i, row in enumerate(mapped, 1):
            msym = row["exchange_symbol"]
            try:
                candles = fetch_ohlcv_month(ex, msym, mstart, mend, "1d")
                for ts,o,h,l,c,v in candles:
                    recs.append({
                        "rank": row["rank"], "symbol": row["symbol"], "name": row.get("name",""),
                        "exchange": ex.id, "exchange_symbol": msym,
                        "time": datetime.utcfromtimestamp(ts/1000).replace(tzinfo=timezone.utc).isoformat(),
                        "open": o, "high": h, "low": l, "close": c, "volume": v,
                        "month_start": mstart.date().isoformat(),
                        "snapshot_date": row["snapshot_date"],
                    })
                if i % 20 == 0 and verbose:
                    LOG.info("[%s] %d/%d markets done", yyyymm, i, len(mapped))
            except ccxt.BaseError as e:
                LOG.warning("[%s] fetch failed %s: %s", yyyymm, msym, e)
        results[yyyymm] = pd.DataFrame(recs)
        if verbose:
            LOG.info("[%s] candles: %d", yyyymm, len(results[yyyymm]))
    return results, top_lists

# %%
dfs, tops = fetch_top200_months(months=12, venue="binance")   # or venue="binanceusdm"
for m, df in dfs.items():
    print(m, df.shape, "tradable:", df["exchange_symbol"].nunique() if not df.empty else 0)
    # peek
    display(df.head())
# Out:
# 2025-10-01 17:38:51,780 INFO CMC snapshot page 2024-11-03  start=1  https://coinmarketcap.com/historical/20241103/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:38:52,630 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:38:52,630 INFO collected so far: 53 (added 53 from this page)
# 2025-10-01 17:38:52,630 INFO CMC snapshot page 2024-11-03  start=101  https://coinmarketcap.com/historical/20241103/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:38:53,180 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:38:53,182 INFO collected so far: 53 (added 0 from this page)
# 2025-10-01 17:38:53,185 INFO [2024-11] ranked symbols=53
# 2025-10-01 17:38:53,198 INFO [2024-11] tradable on binance: 26
# 2025-10-01 17:39:02,843 INFO [2024-11] 20/26 markets done
# 2025-10-01 17:39:05,817 INFO [2024-11] candles: 750
# 2025-10-01 17:39:05,820 INFO CMC snapshot page 2024-12-01  start=1  https://coinmarketcap.com/historical/20241201/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:39:06,455 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:39:06,455 INFO collected so far: 53 (added 53 from this page)
# 2025-10-01 17:39:06,457 INFO CMC snapshot page 2024-12-01  start=101  https://coinmarketcap.com/historical/20241201/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:39:06,952 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:39:06,953 INFO collected so far: 53 (added 0 from this page)
# 2025-10-01 17:39:06,957 INFO [2024-12] ranked symbols=53
# 2025-10-01 17:39:06,973 INFO [2024-12] tradable on binance: 26
# 2025-10-01 17:39:17,295 INFO [2024-12] 20/26 markets done
# 2025-10-01 17:39:20,259 INFO [2024-12] candles: 806
# 2025-10-01 17:39:20,260 INFO CMC snapshot page 2025-01-05  start=1  https://coinmarketcap.com/historical/20250105/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:39:20,912 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:39:20,914 INFO collected so far: 50 (added 50 from this page)
# 2025-10-01 17:39:20,914 INFO CMC snapshot page 2025-01-05  start=101  https://coinmarketcap.com/historical/20250105/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:39:21,424 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:39:21,426 INFO collected so far: 50 (added 0 from this page)
# 2025-10-01 17:39:21,428 INFO [2025-01] ranked symbols=50
# 2025-10-01 17:39:21,440 INFO [2025-01] tradable on binance: 25
# 2025-10-01 17:39:33,412 INFO [2025-01] 20/25 markets done
# 2025-10-01 17:39:35,890 INFO [2025-01] candles: 775
# 2025-10-01 17:39:35,892 INFO CMC snapshot page 2025-02-02  start=1  https://coinmarketcap.com/historical/20250202/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:39:36,480 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:39:36,480 INFO collected so far: 51 (added 51 from this page)
# 2025-10-01 17:39:36,482 INFO CMC snapshot page 2025-02-02  start=101  https://coinmarketcap.com/historical/20250202/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:39:36,980 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:39:36,982 INFO collected so far: 51 (added 0 from this page)
# 2025-10-01 17:39:36,984 INFO [2025-02] ranked symbols=51
# 2025-10-01 17:39:36,998 INFO [2025-02] tradable on binance: 23
# 2025-10-01 17:39:46,893 INFO [2025-02] 20/23 markets done
# 2025-10-01 17:39:48,388 INFO [2025-02] candles: 644
# 2025-10-01 17:39:48,390 INFO CMC snapshot page 2025-03-02  start=1  https://coinmarketcap.com/historical/20250302/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:39:49,167 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:39:49,168 INFO collected so far: 50 (added 50 from this page)
# 2025-10-01 17:39:49,168 INFO CMC snapshot page 2025-03-02  start=101  https://coinmarketcap.com/historical/20250302/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:39:49,876 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:39:49,877 INFO collected so far: 50 (added 0 from this page)
# 2025-10-01 17:39:49,879 INFO [2025-03] ranked symbols=50
# 2025-10-01 17:39:49,891 INFO [2025-03] tradable on binance: 24
# 2025-10-01 17:40:00,192 INFO [2025-03] 20/24 markets done
# 2025-10-01 17:40:02,179 INFO [2025-03] candles: 744
# 2025-10-01 17:40:02,180 INFO CMC snapshot page 2025-04-06  start=1  https://coinmarketcap.com/historical/20250406/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:02,817 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:40:02,818 INFO collected so far: 49 (added 49 from this page)
# 2025-10-01 17:40:02,820 INFO CMC snapshot page 2025-04-06  start=101  https://coinmarketcap.com/historical/20250406/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:03,361 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:40:03,362 INFO collected so far: 49 (added 0 from this page)
# 2025-10-01 17:40:03,365 INFO [2025-04] ranked symbols=49
# 2025-10-01 17:40:03,382 INFO [2025-04] tradable on binance: 22
# 2025-10-01 17:40:13,581 INFO [2025-04] 20/22 markets done
# 2025-10-01 17:40:14,562 INFO [2025-04] candles: 660
# 2025-10-01 17:40:14,562 INFO CMC snapshot page 2025-05-04  start=1  https://coinmarketcap.com/historical/20250504/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:15,246 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:40:15,249 INFO collected so far: 50 (added 50 from this page)
# 2025-10-01 17:40:15,249 INFO CMC snapshot page 2025-05-04  start=101  https://coinmarketcap.com/historical/20250504/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:15,784 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:40:15,784 INFO collected so far: 50 (added 0 from this page)
# 2025-10-01 17:40:15,787 INFO [2025-05] ranked symbols=50
# 2025-10-01 17:40:15,825 INFO [2025-05] tradable on binance: 21
# 2025-10-01 17:40:26,910 INFO [2025-05] 20/21 markets done
# 2025-10-01 17:40:28,238 INFO [2025-05] candles: 646
# 2025-10-01 17:40:28,240 INFO CMC snapshot page 2025-06-01  start=1  https://coinmarketcap.com/historical/20250601/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:28,872 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:40:28,880 INFO collected so far: 49 (added 49 from this page)
# 2025-10-01 17:40:28,881 INFO CMC snapshot page 2025-06-01  start=101  https://coinmarketcap.com/historical/20250601/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:29,502 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:40:29,503 INFO collected so far: 49 (added 0 from this page)
# 2025-10-01 17:40:29,506 INFO [2025-06] ranked symbols=49
# 2025-10-01 17:40:29,517 INFO [2025-06] tradable on binance: 20
# 2025-10-01 17:40:39,804 INFO [2025-06] 20/20 markets done
# 2025-10-01 17:40:39,810 INFO [2025-06] candles: 600
# 2025-10-01 17:40:39,810 INFO CMC snapshot page 2025-07-06  start=1  https://coinmarketcap.com/historical/20250706/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:40,479 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:40:40,480 INFO collected so far: 50 (added 50 from this page)
# 2025-10-01 17:40:40,480 INFO CMC snapshot page 2025-07-06  start=101  https://coinmarketcap.com/historical/20250706/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:41,060 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:40:41,061 INFO collected so far: 50 (added 0 from this page)
# 2025-10-01 17:40:41,063 INFO [2025-07] ranked symbols=50
# 2025-10-01 17:40:41,082 INFO [2025-07] tradable on binance: 20
# 2025-10-01 17:40:51,403 INFO [2025-07] 20/20 markets done
# 2025-10-01 17:40:51,406 INFO [2025-07] candles: 620
# 2025-10-01 17:40:51,406 INFO CMC snapshot page 2025-08-03  start=1  https://coinmarketcap.com/historical/20250803/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:52,276 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:40:52,277 INFO collected so far: 50 (added 50 from this page)
# 2025-10-01 17:40:52,277 INFO CMC snapshot page 2025-08-03  start=101  https://coinmarketcap.com/historical/20250803/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:40:52,812 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:40:52,813 INFO collected so far: 50 (added 0 from this page)
# 2025-10-01 17:40:52,815 INFO [2025-08] ranked symbols=50
# 2025-10-01 17:40:52,829 INFO [2025-08] tradable on binance: 20
# 2025-10-01 17:41:02,859 INFO [2025-08] 20/20 markets done
# 2025-10-01 17:41:02,862 INFO [2025-08] candles: 620
# 2025-10-01 17:41:02,866 INFO CMC snapshot page 2025-09-07  start=1  https://coinmarketcap.com/historical/20250907/?start=1
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:41:03,493 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:41:03,494 INFO collected so far: 50 (added 50 from this page)
# 2025-10-01 17:41:03,494 INFO CMC snapshot page 2025-09-07  start=101  https://coinmarketcap.com/historical/20250907/?start=101
# C:\Users\nahid\AppData\Local\Temp\ipykernel_30088\3426699124.py:53: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(str(tbl))
# 2025-10-01 17:41:04,025 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:41:04,026 INFO collected so far: 50 (added 0 from this page)
# 2025-10-01 17:41:04,030 INFO [2025-09] ranked symbols=50
# 2025-10-01 17:41:04,042 INFO [2025-09] tradable on binance: 18
# 2025-10-01 17:41:12,949 INFO [2025-09] candles: 540
# 2025-10-01 17:41:12,959 INFO CMC snapshot page 2025-10-05  start=1  https://coinmarketcap.com/historical/20251005/?start=1
# 2025-10-01 17:41:13,520 WARNING table parse failed; using fallback heuristic for start=1
# 2025-10-01 17:41:13,521 INFO collected so far: 8 (added 8 from this page)
# 2025-10-01 17:41:13,522 INFO CMC snapshot page 2025-10-05  start=101  https://coinmarketcap.com/historical/20251005/?start=101
# 2025-10-01 17:41:13,969 WARNING table parse failed; using fallback heuristic for start=101
# 2025-10-01 17:41:13,969 INFO collected so far: 8 (added 0 from this page)
# 2025-10-01 17:41:13,976 INFO [2025-10] ranked symbols=8
# 2025-10-01 17:41:13,979 INFO [2025-10] tradable on binance: 2
# 2025-10-01 17:41:14,969 INFO [2025-10] candles: 2
# 2024-11 (750, 13) tradable: 25
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2024-11-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2024-11-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2024-11-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2024-11-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2024-11-05T00:00:00+00:00
#
#        open      high       low     close       volume month_start  \
# 0  70292.01  71632.95  68820.14  69496.01  38301.86755  2024-11-01
# 1  69496.00  69914.37  69000.14  69374.74  10521.67243  2024-11-01
# 2  69374.74  69391.00  67478.73  68775.99  24995.70243  2024-11-01
# 3  68775.99  69500.00  66835.00  67850.01  29800.39187  2024-11-01
# 4  67850.01  70577.91  67476.63  69372.01  33355.06888  2024-11-01
#
#   snapshot_date
# 0    2024-11-03
# 1    2024-11-03
# 2    2024-11-03
# 3    2024-11-03
# 4    2024-11-03
# 2024-12 (806, 13) tradable: 26
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2024-12-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2024-12-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2024-12-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2024-12-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2024-12-05T00:00:00+00:00
#
#        open       high       low     close         volume month_start  \
# 0  96407.99   97836.00  95693.88  97185.18   16938.604520  2024-12-01
# 1  97185.17   98130.00  94395.00  95840.62   37958.669810  2024-12-01
# 2  95840.61   96305.52  93578.17  95849.69   35827.322830  2024-12-01
# 3  95849.69   99000.00  94587.83  98587.32   43850.537280  2024-12-01
# 4  98587.32  104088.00  90500.00  96945.63  109921.729662  2024-12-01
#
#   snapshot_date
# 0    2024-12-01
# 1    2024-12-01
# 2    2024-12-01
# 3    2024-12-01
# 4    2024-12-01
# 2025-01 (775, 13) tradable: 25
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2025-01-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2025-01-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2025-01-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2025-01-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2025-01-05T00:00:00+00:00
#
#        open      high       low     close       volume month_start  \
# 0  93576.00  95151.15  92888.00  94591.79  10373.32613  2025-01-01
# 1  94591.78  97839.50  94392.00  96984.79  21970.48948  2025-01-01
# 2  96984.79  98976.91  96100.01  98174.18  15253.82936  2025-01-01
# 3  98174.17  98778.43  97514.79  98220.50   8990.05651  2025-01-01
# 4  98220.51  98836.85  97276.79  98363.61   8095.63723  2025-01-01
#
#   snapshot_date
# 0    2025-01-05
# 1    2025-01-05
# 2    2025-01-05
# 3    2025-01-05
# 4    2025-01-05
# 2025-02 (644, 13) tradable: 23
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2025-02-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2025-02-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2025-02-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2025-02-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2025-02-05T00:00:00+00:00
#
#         open       high        low      close       volume month_start  \
# 0  102429.56  102783.71  100279.51  100635.65  12290.95747  2025-02-01
# 1  100635.66  101456.60   96150.00   97700.59  34619.49939  2025-02-01
# 2   97700.59  102500.01   91231.00  101328.52  75164.73850  2025-02-01
# 3  101328.51  101732.31   96150.00   97763.13  40267.98697  2025-02-01
# 4   97763.14   99149.00   96155.00   96612.43  26233.30444  2025-02-01
#
#   snapshot_date
# 0    2025-02-02
# 1    2025-02-02
# 2    2025-02-02
# 3    2025-02-02
# 4    2025-02-02
# 2025-03 (744, 13) tradable: 24
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2025-03-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2025-03-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2025-03-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2025-03-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2025-03-05T00:00:00+00:00
#
#        open      high       low     close       volume month_start  \
# 0  84349.95  86558.00  83824.78  86064.53  25785.05464  2025-03-01
# 1  86064.54  95000.00  85050.60  94270.00  54889.09045  2025-03-01
# 2  94269.99  94416.46  85117.11  86220.61  59171.10218  2025-03-01
# 3  86221.16  88967.52  81500.00  87281.98  55609.10706  2025-03-01
# 4  87281.98  91000.00  86334.53  90606.01  38264.01163  2025-03-01
#
#   snapshot_date
# 0    2025-03-02
# 1    2025-03-02
# 2    2025-03-02
# 3    2025-03-02
# 4    2025-03-02
# 2025-04 (660, 13) tradable: 22
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2025-04-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2025-04-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2025-04-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2025-04-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2025-04-05T00:00:00+00:00
#
#        open      high       low     close       volume month_start  \
# 0  82550.00  85579.46  82432.74  85158.34  20190.39697  2025-04-01
# 1  85158.35  88500.00  82320.00  82516.29  39931.45700  2025-04-01
# 2  82516.28  83998.02  81211.24  83213.09  27337.84135  2025-04-01
# 3  83213.09  84720.00  81659.00  83889.87  32915.53976  2025-04-01
# 4  83889.87  84266.00  82379.95  83537.99   9360.40468  2025-04-01
#
#   snapshot_date
# 0    2025-04-06
# 1    2025-04-06
# 2    2025-04-06
# 3    2025-04-06
# 4    2025-04-06
# 2025-05 (646, 13) tradable: 21
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2025-05-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2025-05-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2025-05-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2025-05-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2025-05-05T00:00:00+00:00
#
#        open      high       low     close       volume month_start  \
# 0  94172.00  97424.02  94130.43  96489.91  21380.45343  2025-05-01
# 1  96489.90  97895.68  96350.00  96887.14  14905.74811  2025-05-01
# 2  96887.13  96935.67  95753.01  95856.42   9723.34838  2025-05-01
# 3  95856.42  96304.48  94151.38  94277.62  11036.38342  2025-05-01
# 4  94277.61  95199.00  93514.10  94733.68  17251.18189  2025-05-01
#
#   snapshot_date
# 0    2025-05-04
# 1    2025-05-04
# 2    2025-05-04
# 3    2025-05-04
# 4    2025-05-04
# 2025-06 (600, 13) tradable: 20
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2025-06-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2025-06-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2025-06-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2025-06-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2025-06-05T00:00:00+00:00
#
#         open       high        low      close       volume month_start  \
# 0  104591.88  105866.91  103752.49  105642.93   9709.70006  2025-06-01
# 1  105642.93  105935.63  103659.88  105857.99  13453.98813  2025-06-01
# 2  105858.00  106794.67  104872.50  105376.89  13259.52634  2025-06-01
# 3  105376.90  106000.00  104179.00  104696.86  14034.89482  2025-06-01
# 4  104696.86  105909.71  100372.26  101508.68  22321.50154  2025-06-01
#
#   snapshot_date
# 0    2025-06-01
# 1    2025-06-01
# 2    2025-06-01
# 3    2025-06-01
# 4    2025-06-01
# 2025-07 (620, 13) tradable: 20
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2025-07-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2025-07-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2025-07-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2025-07-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2025-07-05T00:00:00+00:00
#
#         open       high        low      close       volume month_start  \
# 0  107146.51  107540.00  105250.85  105681.14  10505.62437  2025-07-01
# 1  105681.13  109730.00  105100.19  108849.60  17691.89592  2025-07-01
# 2  108849.59  110529.18  108530.40  109584.78  13047.08225  2025-07-01
# 3  109584.77  109767.59  107245.00  107984.24  11793.86615  2025-07-01
# 4  107984.25  108420.56  107756.31  108198.12   3736.97570  2025-07-01
#
#   snapshot_date
# 0    2025-07-06
# 1    2025-07-06
# 2    2025-07-06
# 3    2025-07-06
# 4    2025-07-06
# 2025-08 (620, 13) tradable: 20
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2025-08-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2025-08-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2025-08-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2025-08-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2025-08-05T00:00:00+00:00
#
#         open       high        low      close       volume month_start  \
# 0  115764.07  116052.00  112722.58  113297.93  24487.10206  2025-08-01
# 1  113297.92  114063.49  112003.00  112546.35  11507.33428  2025-08-01
# 2  112546.35  114799.97  111920.00  114208.80   7397.76046  2025-08-01
# 3  114208.81  115720.00  114107.60  115055.03   9667.67916  2025-08-01
# 4  115055.03  115127.81  112650.00  114129.75  12042.79078  2025-08-01
#
#   snapshot_date
# 0    2025-08-03
# 1    2025-08-03
# 2    2025-08-03
# 3    2025-08-03
# 4    2025-08-03
# 2025-09 (540, 13) tradable: 18
#    rank symbol name exchange exchange_symbol                       time  \
# 0     2    BTC       binance        BTC/USDT  2025-09-01T00:00:00+00:00
# 1     2    BTC       binance        BTC/USDT  2025-09-02T00:00:00+00:00
# 2     2    BTC       binance        BTC/USDT  2025-09-03T00:00:00+00:00
# 3     2    BTC       binance        BTC/USDT  2025-09-04T00:00:00+00:00
# 4     2    BTC       binance        BTC/USDT  2025-09-05T00:00:00+00:00
#
#         open       high        low      close       volume month_start  \
# 0  108246.36  109912.40  107255.00  109237.42  16053.60219  2025-09-01
# 1  109237.43  111771.52  108393.39  111240.01  18510.28756  2025-09-01
# 2  111240.01  112575.27  110528.71  111705.71  11773.72084  2025-09-01
# 3  111705.72  112180.00  109329.12  110730.87  12203.13536  2025-09-01
# 4  110730.87  113384.62  110206.96  110659.99  21587.40888  2025-09-01
#
#   snapshot_date
# 0    2025-09-07
# 1    2025-09-07
# 2    2025-09-07
# 3    2025-09-07
# 4    2025-09-07
# 2025-10 (2, 13) tradable: 2
#    rank symbol name exchange exchange_symbol                       time  \
# 0     4    BTC       binance        BTC/USDT  2025-10-01T00:00:00+00:00
# 1     5    ETH       binance        ETH/USDT  2025-10-01T00:00:00+00:00
#
#         open      high        low      close        volume month_start  \
# 0  114048.94  118199.0  113966.67  118025.58   15237.89066  2025-10-01
# 1    4145.15    4344.0    4123.08    4335.51  390669.92290  2025-10-01
#
#   snapshot_date
# 0    2025-10-05
# 1    2025-10-05

# %%
dfs.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dfs.shape
#
# NameError: name 'dfs' is not defined

# %%
dfs['2024-10'].loc[dfs['2024-10']['symbol']=='BTC']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dfs['2024-10'].loc[dfs['2024-10']['symbol']=='BTC']
#
# KeyError: '2024-10'

# %%
# see the size of dfs and tops
print("dfs keys:", list(dfs.keys()))
print("tops keys:", list(tops.keys()))
# Out:
# dfs keys: ['2024-11', '2024-12', '2025-01', '2025-02', '2025-03', '2025-04', '2025-05', '2025-06', '2025-07', '2025-08', '2025-09', '2025-10']
# tops keys: ['2024-11', '2024-12', '2025-01', '2025-02', '2025-03', '2025-04', '2025-05', '2025-06', '2025-07', '2025-08', '2025-09', '2025-10']

# %%
# I want to save dfs and tops to csv files so that I can load them later without re-fetching
import os
os.makedirs("data", exist_ok=True)
for m, df in dfs.items():
    df.to_csv(f"data/ohlcv_{m}.csv", index=False)
for m, df in tops.items():
    df.to_csv(f"data/top200_{m}.csv", index=False)

# %%
# Load saved data
import pandas as pd
import os
data_dir = "data"

for fname in os.listdir(data_dir):
    if fname.startswith("ohlcv_") and fname.endswith(".csv"):
        m = fname[len("ohlcv_"):-len(".csv")]
        path = os.path.join(data_dir, fname)
        df = pd.read_csv(path)
        dfs[m] = df
        print(f"Loaded {m}: {df.shape}")
    elif fname.startswith("top200_") and fname.endswith(".csv"):
        m = fname[len("top200_"):-len(".csv")]
        path = os.path.join(data_dir, fname)
        df = pd.read_csv(path)
        tops[m] = df
        print(f"Loaded top {m}: {df.shape}")
# Out:
# Loaded 2024-11: (750, 13)
# Loaded 2024-12: (806, 13)
# Loaded 2025-01: (775, 13)
# Loaded 2025-02: (644, 13)
# Loaded 2025-03: (744, 13)
# Loaded 2025-04: (660, 13)
# Loaded 2025-05: (646, 13)
# Loaded 2025-06: (600, 13)
# Loaded 2025-07: (620, 13)
# Loaded 2025-08: (620, 13)
# Loaded 2025-09: (540, 13)
# Loaded 2025-10: (2, 13)
# Loaded top 2024-11: (53, 4)
# Loaded top 2024-12: (53, 4)
# Loaded top 2025-01: (50, 4)
# Loaded top 2025-02: (51, 4)
# Loaded top 2025-03: (50, 4)
# Loaded top 2025-04: (49, 4)
# Loaded top 2025-05: (50, 4)
# Loaded top 2025-06: (49, 4)
# Loaded top 2025-07: (50, 4)
# Loaded top 2025-08: (50, 4)
# Loaded top 2025-09: (50, 4)
# Loaded top 2025-10: (8, 4)

# %%
# --- paste to replace CG networking + prefetch (adds strict timeouts, attempt logs, jitter, and no double logs) ---

import time, json, math, hashlib, random, requests, logging
from pathlib import Path
from datetime import datetime, timezone

from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

# logger: prevent duplicate lines across re-execs
LOG = logging.getLogger("cg_top200_nb")
if not getattr(LOG, "_configured", False):
    h = logging.StreamHandler()
    h.setFormatter(logging.Formatter("%(asctime)s %(levelname)s %(message)s"))
    LOG.addHandler(h)
    LOG.setLevel(logging.INFO)
    LOG.propagate = False
    LOG._configured = True

CG_BASE = "https://api.coingecko.com/api/v3"
CG_CACHE_DIR = Path("./.cg_cache"); CG_CACHE_DIR.mkdir(parents=True, exist_ok=True)

# conservative defaults (tune here)
CONNECT_TIMEOUT = 5          # seconds
READ_TIMEOUT    = 12         # seconds (keeps single read under ~12s)
MAX_ATTEMPTS    = 4
BACKOFF_BASE    = 0.8        # exponential backoff base
POLITE_DELAY    = 0.45       # base inter-request delay
SLOW_LOG_SEC    = 5.0        # log when a single attempt exceeds this
USE_DAILY_ENDPOINT = True    # True => /market_chart?days=… (usually faster/cached)

# requests session + retries for transient 5xx (we do manual retry loop too)
sess = requests.Session()
adapter = HTTPAdapter(max_retries=Retry(total=0))  # disable urllib3 auto-retries; we do our own so it’s visible
sess.mount("https://", adapter)
sess.headers.update({"User-Agent": "cg-top200-notebook/1.1"})

def _cache_path(prefix: str, key: str) -> Path:
    h = hashlib.sha256(key.encode()).hexdigest()[:32]
    return CG_CACHE_DIR / f"{prefix}_{h}.json"

def cache_get(prefix: str, key: str):
    p = _cache_path(prefix, key)
    if p.exists():
        try:
            return json.loads(p.read_text())
        except Exception:
            return None
    return None

def cache_put(prefix: str, key: str, obj):
    _cache_path(prefix, key).write_text(json.dumps(obj))

def cg_get(path: str, params: dict, *, attempts=MAX_ATTEMPTS):
    """GET with strict per-attempt timeouts, explicit retry logs, and 429 handling."""
    url = f"{CG_BASE}{path}"
    key = url + "?" + "&".join(f"{k}={v}" for k,v in sorted(params.items()))
    cached = cache_get("cg", key)
    if cached is not None:
        LOG.debug("CG cache hit %s", path)
        return cached

    for k in range(1, attempts + 1):
        # jitter to avoid global thundering herd
        time.sleep(POLITE_DELAY + random.uniform(0, 0.25))
        t0 = time.perf_counter()
        try:
            LOG.info("CG attempt %d/%d %s params=%s", k, attempts, path, params)
            r = sess.get(url, params=params, timeout=(CONNECT_TIMEOUT, READ_TIMEOUT))
            dt = time.perf_counter() - t0
            if dt > SLOW_LOG_SEC:
                LOG.warning("CG SLOW %s dt=%.2fs", path, dt)
            if r.status_code == 429:
                ra = r.headers.get("Retry-After")
                sleep_s = float(ra) if ra and str(ra).isdigit() else BACKOFF_BASE * (2 ** (k - 1))
                LOG.warning("CG 429 %s; sleeping %.2fs then retry", path, sleep_s)
                time.sleep(sleep_s)
                continue
            if 500 <= r.status_code < 600:
                LOG.warning("CG %s %s; retrying", path, r.status_code)
                time.sleep(BACKOFF_BASE * (2 ** (k - 1)))
                continue
            r.raise_for_status()
            data = r.json()
            cache_put("cg", key, data)
            LOG.info("CG ok %s status=%s dt=%.2fs", path, r.status_code, dt)
            return data
        except (requests.Timeout, requests.ConnectionError) as e:
            dt = time.perf_counter() - t0
            LOG.warning("CG TIMEOUT/CONN %s after %.2fs (attempt %d/%d): %s", path, dt, k, attempts, str(e)[:160])
            time.sleep(BACKOFF_BASE * (2 ** (k - 1)))
        except requests.RequestException as e:
            LOG.warning("CG ERROR %s (attempt %d/%d): %s", path, k, attempts, str(e)[:160])
            time.sleep(BACKOFF_BASE * (2 ** (k - 1)))
    raise RuntimeError(f"CG GET failed after {attempts} attempts: {path} params={params}")

def cg_top_now(n: int = 600, vs="usd"):
    pages = math.ceil(n / 250)
    rows, rank = [], 1
    for p in range(1, pages + 1):
        per = 250 if p < pages else (n - 250 * (pages - 1))
        per = max(per, 1)
        data = cg_get("/coins/markets", {
            "vs_currency": vs, "order": "market_cap_desc",
            "per_page": per, "page": p, "sparkline": "false",
        })
        for d in data:
            rows.append({"id": d["id"], "symbol": str(d["symbol"]).upper(), "name": d["name"], "rank_now": rank})
            rank += 1
        LOG.info("top_now progress: %d/%d", len(rows), n)
    df = pd.DataFrame(rows)
    LOG.info("top_now gathered: %d", len(df))
    return df

def cg_market_caps_series(coin_id: str, start_dt: datetime, end_dt: datetime, vs="usd"):
    """Prefer daily series endpoint (faster, cached); fallback to range."""
    if USE_DAILY_ENDPOINT:
        days = max(1, int((end_dt - start_dt).days) + 6)
        data = cg_get(f"/coins/{coin_id}/market_chart", {
            "vs_currency": vs, "days": days, "interval": "daily"
        })
        return (data.get("market_caps") or [])
    else:
        data = cg_get(f"/coins/{coin_id}/market_chart/range", {
            "vs_currency": vs, "from": int(start_dt.replace(tzinfo=timezone.utc).timestamp()),
            "to": int(end_dt.replace(tzinfo=timezone.utc).timestamp())
        })
        return (data.get("market_caps") or [])

def prefetch_mcap_ranges(coin_ids, start_dt, end_dt, vs="usd", log_every=25):
    series = {}
    N = len(coin_ids)
    LOG.info("prefetch market_caps for %d coins [%s → %s] (daily=%s)", N, start_dt.date(), end_dt.date(), USE_DAILY_ENDPOINT)
    for i, cid in enumerate(coin_ids, 1):
        t0 = time.perf_counter()
        try:
            series[cid] = cg_market_caps_series(cid, start_dt, end_dt, vs=vs)
        except Exception as e:
            LOG.warning("prefetch FAIL id=%s (%d/%d): %s", cid, i, N, str(e)[:160])
            series[cid] = []
        dt = time.perf_counter() - t0
        if i % log_every == 0 or dt > SLOW_LOG_SEC:
            LOG.info("prefetch %d/%d id=%s caps_pts=%d dt=%.2fs", i, N, cid, len(series[cid]), dt)
    return series

def cap_on_or_near(date_dt, caps_series, max_lag_days: int = 5):
    if not caps_series: return None
    target = int(date_dt.replace(tzinfo=timezone.utc).timestamp()) * 1000
    best = min(caps_series, key=lambda x: abs(x[0] - target))
    if abs(best[0] - target) > max_lag_days * 86400_000:
        return None
    return float(best[1]) if best and best[1] is not None else None


# ----------------- Exchange + OHLCV -------
def build_exchange(venue="binance"):
    if venue not in ("binance", "binanceusdm"):
        raise ValueError("venue must be binance|binanceusdm")
    ex = getattr(ccxt, venue)({"enableRateLimit": True, "options": {"adjustForTimeDifference": True}})
    ex.load_markets()
    LOG.info("loaded markets for %s: %d", ex.id, len(ex.markets))
    return ex

def pick_market_symbol(ex, base_symbol: str, venue: str, quote="USDT") -> Optional[str]:
    bsym = SYMBOL_NORMALIZE.get(base_symbol.upper(), base_symbol.upper())
    cands = [f"{bsym}/{quote}"] if venue == "binance" else [f"{bsym}/{quote}:USDT", f"{bsym}/{quote}"]
    for s in cands:
        m = ex.markets.get(s)
        if not m: continue
        if venue == "binance" and m.get("spot"): return s
        if venue == "binanceusdm" and (m.get("swap") or m.get("contract")): return s
    for m in ex.markets.values():
        if m.get("base") == bsym:
            if venue == "binance" and m.get("spot") and m.get("quote") == quote: return m["symbol"]
            if venue == "binanceusdm" and (m.get("swap") or m.get("contract")) and quote in m["symbol"]: return m["symbol"]
    return None

def fetch_ohlcv_month(ex, symbol: str, start: datetime, end: datetime, timeframe="1d") -> List[List]:
    start_ms = int(start.timestamp() * 1000)
    end_ms   = int(end.timestamp() * 1000) - 1
    out = []
    cursor = start_ms
    LOG.info("OHLCV %s %s [%s → %s]", ex.id, symbol, datetime.utcfromtimestamp(start_ms/1000).date(), datetime.utcfromtimestamp((end_ms+1)/1000).date())
    while True:
        params = {}
        if ex.id in ("binance", "binanceusdm"): params["endTime"] = end_ms
        t0 = time.perf_counter()
        chunk = ex.fetch_ohlcv(symbol, timeframe=timeframe, since=cursor, limit=1500, params=params)
        dt = time.perf_counter() - t0
        LOG.debug("fetch_ohlcv chunk n=%d cursor=%s dt=%.2fs", len(chunk), cursor, dt)
        if not chunk: break
        out.extend(chunk)
        last_ts = chunk[-1][0]
        if last_ts >= end_ms: break
        cursor = last_ts + 60_000
        time.sleep(ex.rateLimit / 1000)
    out = [row for row in out if start_ms <= row[0] <= end_ms]
    LOG.info("OHLCV got %d rows for %s", len(out), symbol)
    return out

# ----------------- main driver ------------
def fetch_monthly_top200_ohlcv(
    months: int = 12,
    venue: str = "binance",
    quote: str = "USDT",
    top_now_n: int = 600,
    per_month_k: int = 200,
    vs_currency: str = "usd",
    verbose: bool = True,
    rank_only: bool = False,
    max_lag_days: int = 5,
):
    """
    1) Pull today's top_now_n from CG (coins/markets, paginated).
    2) Prefetch market_caps once per coin over the full [first-3d, last+3d] span.
    3) Rank each month by nearest cap to month start; take top per_month_k.
    4) If rank_only=False, fetch month OHLCV from ccxt for the mapped markets.
    """
    now = datetime.now(timezone.utc)
    bounds = month_bounds_utc(now, months)
    first_start = bounds[0][0] - timedelta(days=3)
    last_end    = bounds[-1][1] + timedelta(days=3)

    # 1) candidates
    cand = cg_top_now(n=top_now_n, vs=vs_currency)

    # 2) prefetch series
    caps_series = prefetch_mcap_ranges(cand["id"].tolist(), first_start, last_end, vs=vs_currency)

    # 3) rank per month
    cohorts_by_month: Dict[str, pd.DataFrame] = {}
    for (mstart, mend) in bounds:
        yyyymm = mstart.strftime("%Y-%m")
        LOG.info("[%s] ranking by market cap at %sZ", yyyymm, mstart.isoformat())
        rows = []
        miss = 0
        for _, r in cand.iterrows():
            caps = caps_series.get(r["id"], [])
            cap  = cap_on_or_near(mstart, caps, max_lag_days=max_lag_days)
            if cap is None:
                miss += 1
                continue
            rows.append({"cg_id": r["id"], "cg_symbol": r["symbol"], "cg_name": r["name"], "mcap_month_start": cap})
        cohort = pd.DataFrame(rows)
        cohort.sort_values("mcap_month_start", ascending=False, inplace=True, ignore_index=True)
        cohort["rank_month"] = cohort.index + 1
        cohort = cohort.head(per_month_k)
        LOG.info("[%s] cohort size=%d (missing caps=%d)", yyyymm, len(cohort), miss)
        cohorts_by_month[yyyymm] = cohort

    if rank_only:
        return {m: pd.DataFrame() for m in cohorts_by_month}, cohorts_by_month

    # 4) OHLCV
    ex = build_exchange(venue)
    ohlcv_by_month: Dict[str, pd.DataFrame] = {}
    for (mstart, mend) in bounds:
        yyyymm = mstart.strftime("%Y-%m")
        cohort = cohorts_by_month[yyyymm]
        LOG.info("[%s] mapping to %s markets", yyyymm, ex.id)
        mapped = []
        for _, rr in cohort.iterrows():
            msym = pick_market_symbol(ex, rr["cg_symbol"], venue, quote=quote)
            if msym:
                mapped.append({**rr.to_dict(), "exchange": ex.id, "exchange_symbol": msym})
        LOG.info("[%s] tradable markets=%d", yyyymm, len(mapped))

        recs = []
        for i, rr in enumerate(mapped, 1):
            LOG.info("[%s] (%d/%d) OHLCV %s", yyyymm, i, len(mapped), rr["exchange_symbol"])
            try:
                cs = fetch_ohlcv_month(ex, rr["exchange_symbol"], mstart, mend, "1d")
                for t,o,h,l,c,v in cs:
                    recs.append({
                        "rank_month": int(rr["rank_month"]),
                        "cg_id": rr["cg_id"], "cg_symbol": rr["cg_symbol"], "cg_name": rr["cg_name"],
                        "exchange": rr["exchange"], "exchange_symbol": rr["exchange_symbol"],
                        "time": datetime.utcfromtimestamp(t/1000).replace(tzinfo=timezone.utc).isoformat(),
                        "open": o, "high": h, "low": l, "close": c, "volume": v,
                        "month_start": mstart.date().isoformat(),
                    })
            except ccxt.BaseError as e:
                LOG.warning("[%s] fetch failed %s: %s", yyyymm, rr["exchange_symbol"], str(e)[:160])
        ohlcv_by_month[yyyymm] = pd.DataFrame(recs)

    return ohlcv_by_month, cohorts_by_month

# %%
# dial up verbosity if you want wire-level detail
LOG.setLevel(logging.DEBUG)

# fast sanity: rank only
_, cohorts = fetch_monthly_top200_ohlcv(months=3, rank_only=True, top_now_n=400)

# full pull (start small to validate)
ohlcv, cohorts = fetch_monthly_top200_ohlcv(months=3, venue="binance", top_now_n=400, per_month_k=200)

for m, df in ohlcv.items():
    print(m, df.shape, "uniq markets:", df["exchange_symbol"].nunique() if not df.empty else 0)
    display(cohorts[m].head(10))
    display(df.head())
# Out:
# 2025-10-01 17:43:51,829 DEBUG CG cache hit /coins/markets
# 2025-10-01 17:43:51,830 INFO top_now progress: 250/400
# 2025-10-01 17:43:51,849 DEBUG CG cache hit /coins/markets
# 2025-10-01 17:43:51,850 INFO top_now progress: 400/400
# 2025-10-01 17:43:51,852 INFO top_now gathered: 400
# 2025-10-01 17:43:51,853 INFO prefetch market_caps for 400 coins [2025-07-29 → 2025-11-04] (daily=True)
# 2025-10-01 17:43:51,870 DEBUG CG cache hit /coins/bitcoin/market_chart
# 2025-10-01 17:43:51,884 DEBUG CG cache hit /coins/ethereum/market_chart
# 2025-10-01 17:43:51,900 DEBUG CG cache hit /coins/ripple/market_chart
# 2025-10-01 17:43:51,916 DEBUG CG cache hit /coins/tether/market_chart
# 2025-10-01 17:43:51,933 DEBUG CG cache hit /coins/binancecoin/market_chart
# 2025-10-01 17:43:51,950 DEBUG CG cache hit /coins/solana/market_chart
# 2025-10-01 17:43:51,970 DEBUG CG cache hit /coins/usd-coin/market_chart
# 2025-10-01 17:43:51,992 DEBUG CG cache hit /coins/staked-ether/market_chart
# 2025-10-01 17:43:52,015 DEBUG CG cache hit /coins/dogecoin/market_chart
# 2025-10-01 17:43:52,050 DEBUG CG cache hit /coins/tron/market_chart
# 2025-10-01 17:43:52,071 DEBUG CG cache hit /coins/cardano/market_chart
# 2025-10-01 17:43:52,094 DEBUG CG cache hit /coins/wrapped-steth/market_chart
# 2025-10-01 17:43:52,109 DEBUG CG cache hit /coins/wrapped-beacon-eth/market_chart
# 2025-10-01 17:43:52,123 DEBUG CG cache hit /coins/chainlink/market_chart
# 2025-10-01 17:43:52,139 DEBUG CG cache hit /coins/wrapped-bitcoin/market_chart
# 2025-10-01 17:43:52,172 DEBUG CG cache hit /coins/ethena-usde/market_chart
# 2025-10-01 17:43:52,192 DEBUG CG cache hit /coins/figure-heloc/market_chart
# 2025-10-01 17:43:52,213 DEBUG CG cache hit /coins/avalanche-2/market_chart
# 2025-10-01 17:43:52,230 DEBUG CG cache hit /coins/hyperliquid/market_chart
# 2025-10-01 17:43:52,249 DEBUG CG cache hit /coins/sui/market_chart
# 2025-10-01 17:43:52,265 DEBUG CG cache hit /coins/stellar/market_chart
# 2025-10-01 17:43:52,283 DEBUG CG cache hit /coins/bitcoin-cash/market_chart
# 2025-10-01 17:43:52,297 DEBUG CG cache hit /coins/wrapped-eeth/market_chart
# 2025-10-01 17:43:52,315 DEBUG CG cache hit /coins/weth/market_chart
# 2025-10-01 17:43:52,330 DEBUG CG cache hit /coins/hedera-hashgraph/market_chart
# 2025-10-01 17:43:52,331 INFO prefetch 25/400 id=hedera-hashgraph caps_pts=105 dt=0.02s
# 2025-10-01 17:43:52,345 DEBUG CG cache hit /coins/leo-token/market_chart
# 2025-10-01 17:43:52,361 DEBUG CG cache hit /coins/litecoin/market_chart
# 2025-10-01 17:43:52,379 DEBUG CG cache hit /coins/usds/market_chart
# 2025-10-01 17:43:52,393 DEBUG CG cache hit /coins/binance-bridged-usdt-bnb-smart-chain/market_chart
# 2025-10-01 17:43:52,409 DEBUG CG cache hit /coins/coinbase-wrapped-btc/market_chart
# 2025-10-01 17:43:52,425 DEBUG CG cache hit /coins/shiba-inu/market_chart
# 2025-10-01 17:43:52,441 DEBUG CG cache hit /coins/usdt0/market_chart
# 2025-10-01 17:43:52,457 DEBUG CG cache hit /coins/crypto-com-chain/market_chart
# 2025-10-01 17:43:52,471 DEBUG CG cache hit /coins/the-open-network/market_chart
# 2025-10-01 17:43:52,490 DEBUG CG cache hit /coins/polkadot/market_chart
# 2025-10-01 17:43:52,507 DEBUG CG cache hit /coins/whitebit/market_chart
# 2025-10-01 17:43:52,524 DEBUG CG cache hit /coins/mantle/market_chart
# 2025-10-01 17:43:52,540 DEBUG CG cache hit /coins/ethena-staked-usde/market_chart
# 2025-10-01 17:43:52,555 DEBUG CG cache hit /coins/monero/market_chart
# 2025-10-01 17:43:52,569 DEBUG CG cache hit /coins/world-liberty-financial/market_chart
# 2025-10-01 17:43:52,585 DEBUG CG cache hit /coins/uniswap/market_chart
# 2025-10-01 17:43:52,604 DEBUG CG cache hit /coins/dai/market_chart
# 2025-10-01 17:43:52,620 DEBUG CG cache hit /coins/aave/market_chart
# 2025-10-01 17:43:52,643 DEBUG CG cache hit /coins/pepe/market_chart
# 2025-10-01 17:43:52,656 DEBUG CG cache hit /coins/ethena/market_chart
# 2025-10-01 17:43:52,669 DEBUG CG cache hit /coins/okb/market_chart
# 2025-10-01 17:43:52,682 DEBUG CG cache hit /coins/memecore/market_chart
# 2025-10-01 17:43:52,695 DEBUG CG cache hit /coins/bitget-token/market_chart
# 2025-10-01 17:43:52,713 DEBUG CG cache hit /coins/near/market_chart
# 2025-10-01 17:43:52,728 DEBUG CG cache hit /coins/jito-staked-sol/market_chart
# 2025-10-01 17:43:52,729 INFO prefetch 50/400 id=jito-staked-sol caps_pts=105 dt=0.01s
# 2025-10-01 17:43:52,744 DEBUG CG cache hit /coins/aptos/market_chart
# 2025-10-01 17:43:52,761 DEBUG CG cache hit /coins/myx-finance/market_chart
# 2025-10-01 17:43:52,775 DEBUG CG cache hit /coins/bittensor/market_chart
# 2025-10-01 17:43:52,790 DEBUG CG cache hit /coins/ethereum-classic/market_chart
# 2025-10-01 17:43:52,804 DEBUG CG cache hit /coins/ondo-finance/market_chart
# 2025-10-01 17:43:52,817 DEBUG CG cache hit /coins/worldcoin-wld/market_chart
# 2025-10-01 17:43:52,837 DEBUG CG cache hit /coins/story-2/market_chart
# 2025-10-01 17:43:52,853 DEBUG CG cache hit /coins/binance-staked-sol/market_chart
# 2025-10-01 17:43:52,867 DEBUG CG cache hit /coins/aster-2/market_chart
# 2025-10-01 17:43:52,880 DEBUG CG cache hit /coins/usd1-wlfi/market_chart
# 2025-10-01 17:43:52,915 DEBUG CG cache hit /coins/blackrock-usd-institutional-digital-liquidity-fund/market_chart
# 2025-10-01 17:43:52,936 DEBUG CG cache hit /coins/binance-peg-weth/market_chart
# 2025-10-01 17:43:52,953 DEBUG CG cache hit /coins/polygon-ecosystem-token/market_chart
# 2025-10-01 17:43:52,969 DEBUG CG cache hit /coins/paypal-usd/market_chart
# 2025-10-01 17:43:52,986 DEBUG CG cache hit /coins/pump-fun/market_chart
# 2025-10-01 17:43:53,006 DEBUG CG cache hit /coins/internet-computer/market_chart
# 2025-10-01 17:43:53,023 DEBUG CG cache hit /coins/arbitrum/market_chart
# 2025-10-01 17:43:53,040 DEBUG CG cache hit /coins/jupiter-perpetuals-liquidity-provider-token/market_chart
# 2025-10-01 17:43:53,057 DEBUG CG cache hit /coins/pi-network/market_chart
# 2025-10-01 17:43:53,071 DEBUG CG cache hit /coins/susds/market_chart
# 2025-10-01 17:43:53,086 DEBUG CG cache hit /coins/kaspa/market_chart
# 2025-10-01 17:43:53,103 DEBUG CG cache hit /coins/kucoin-shares/market_chart
# 2025-10-01 17:43:53,124 DEBUG CG cache hit /coins/cosmos/market_chart
# 2025-10-01 17:43:53,140 DEBUG CG cache hit /coins/pudgy-penguins/market_chart
# 2025-10-01 17:43:53,159 DEBUG CG cache hit /coins/vechain/market_chart
# 2025-10-01 17:43:53,159 INFO prefetch 75/400 id=vechain caps_pts=105 dt=0.02s
# 2025-10-01 17:43:53,176 DEBUG CG cache hit /coins/gatechain-token/market_chart
# 2025-10-01 17:43:53,194 DEBUG CG cache hit /coins/rocket-pool-eth/market_chart
# 2025-10-01 17:43:53,209 DEBUG CG cache hit /coins/algorand/market_chart
# 2025-10-01 17:43:53,226 DEBUG CG cache hit /coins/flare-networks/market_chart
# 2025-10-01 17:43:53,239 DEBUG CG cache hit /coins/kelp-dao-restaked-eth/market_chart
# 2025-10-01 17:43:53,256 DEBUG CG cache hit /coins/kinetic-staked-hype/market_chart
# 2025-10-01 17:43:53,268 DEBUG CG cache hit /coins/plasma/market_chart
# 2025-10-01 17:43:53,281 DEBUG CG cache hit /coins/usdtb/market_chart
# 2025-10-01 17:43:53,304 DEBUG CG cache hit /coins/render-token/market_chart
# 2025-10-01 17:43:53,319 DEBUG CG cache hit /coins/sei-network/market_chart
# 2025-10-01 17:43:53,334 DEBUG CG cache hit /coins/hash-2/market_chart
# 2025-10-01 17:43:53,352 DEBUG CG cache hit /coins/falcon-finance/market_chart
# 2025-10-01 17:43:53,370 DEBUG CG cache hit /coins/bfusd/market_chart
# 2025-10-01 17:43:53,387 DEBUG CG cache hit /coins/sky/market_chart
# 2025-10-01 17:43:53,406 DEBUG CG cache hit /coins/stakewise-v3-oseth/market_chart
# 2025-10-01 17:43:53,423 DEBUG CG cache hit /coins/bonk/market_chart
# 2025-10-01 17:43:53,440 DEBUG CG cache hit /coins/filecoin/market_chart
# 2025-10-01 17:43:53,456 DEBUG CG cache hit /coins/liquid-staked-ethereum/market_chart
# 2025-10-01 17:43:53,473 DEBUG CG cache hit /coins/fetch-ai/market_chart
# 2025-10-01 17:43:53,491 DEBUG CG cache hit /coins/official-trump/market_chart
# 2025-10-01 17:43:53,506 DEBUG CG cache hit /coins/quant-network/market_chart
# 2025-10-01 17:43:53,524 DEBUG CG cache hit /coins/zcash/market_chart
# 2025-10-01 17:43:53,540 DEBUG CG cache hit /coins/jupiter-exchange-solana/market_chart
# 2025-10-01 17:43:53,557 DEBUG CG cache hit /coins/tether-gold/market_chart
# 2025-10-01 17:43:53,571 DEBUG CG cache hit /coins/lombard-staked-btc/market_chart
# 2025-10-01 17:43:53,572 INFO prefetch 100/400 id=lombard-staked-btc caps_pts=105 dt=0.01s
# 2025-10-01 17:43:53,587 DEBUG CG cache hit /coins/renzo-restaked-eth/market_chart
# 2025-10-01 17:43:53,601 DEBUG CG cache hit /coins/immutable-x/market_chart
# 2025-10-01 17:43:53,617 DEBUG CG cache hit /coins/xdce-crowd-sale/market_chart
# 2025-10-01 17:43:53,631 DEBUG CG cache hit /coins/nexo/market_chart
# 2025-10-01 17:43:54,310 INFO CG attempt 1/4 /coins/wbnb/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:43:54,979 INFO CG ok /coins/wbnb/market_chart status=200 dt=0.67s
# 2025-10-01 17:43:55,604 INFO CG attempt 1/4 /coins/optimism/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:43:55,845 INFO CG ok /coins/optimism/market_chart status=200 dt=0.24s
# 2025-10-01 17:43:56,330 INFO CG attempt 1/4 /coins/injective-protocol/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:43:56,511 INFO CG ok /coins/injective-protocol/market_chart status=200 dt=0.18s
# 2025-10-01 17:43:57,139 INFO CG attempt 1/4 /coins/solv-btc/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:43:57,381 INFO CG ok /coins/solv-btc/market_chart status=200 dt=0.24s
# 2025-10-01 17:43:58,030 INFO CG attempt 1/4 /coins/pax-gold/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:43:58,261 INFO CG ok /coins/pax-gold/market_chart status=200 dt=0.23s
# 2025-10-01 17:43:58,925 INFO CG attempt 1/4 /coins/celestia/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:43:58,941 WARNING CG 429 /coins/celestia/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:44:59,632 INFO CG attempt 2/4 /coins/celestia/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:44:59,791 INFO CG ok /coins/celestia/market_chart status=200 dt=0.16s
# 2025-10-01 17:44:59,791 INFO prefetch 110/400 id=celestia caps_pts=105 dt=61.53s
# 2025-10-01 17:45:00,294 INFO CG attempt 1/4 /coins/binance-bridged-usdc-bnb-smart-chain/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:45:00,564 INFO CG ok /coins/binance-bridged-usdc-bnb-smart-chain/market_chart status=200 dt=0.27s
# 2025-10-01 17:45:01,268 INFO CG attempt 1/4 /coins/jupiter-staked-sol/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:45:01,521 INFO CG ok /coins/jupiter-staked-sol/market_chart status=200 dt=0.25s
# 2025-10-01 17:45:02,165 INFO CG attempt 1/4 /coins/syrupusdc/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:45:02,412 INFO CG ok /coins/syrupusdc/market_chart status=200 dt=0.25s
# 2025-10-01 17:45:03,027 INFO CG attempt 1/4 /coins/mantle-staked-ether/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:45:03,273 INFO CG ok /coins/mantle-staked-ether/market_chart status=200 dt=0.24s
# 2025-10-01 17:45:03,770 INFO CG attempt 1/4 /coins/first-digital-usd/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:45:03,802 WARNING CG 429 /coins/first-digital-usd/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:46:04,264 INFO CG attempt 2/4 /coins/first-digital-usd/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:46:04,521 INFO CG ok /coins/first-digital-usd/market_chart status=200 dt=0.26s
# 2025-10-01 17:46:04,521 INFO prefetch 115/400 id=first-digital-usd caps_pts=105 dt=61.25s
# 2025-10-01 17:46:05,170 INFO CG attempt 1/4 /coins/blockstack/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:46:05,406 INFO CG ok /coins/blockstack/market_chart status=200 dt=0.24s
# 2025-10-01 17:46:05,885 INFO CG attempt 1/4 /coins/lido-dao/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:46:06,206 INFO CG ok /coins/lido-dao/market_chart status=200 dt=0.32s
# 2025-10-01 17:46:06,871 INFO CG attempt 1/4 /coins/sonic-3/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:46:07,050 INFO CG ok /coins/sonic-3/market_chart status=200 dt=0.18s
# 2025-10-01 17:46:07,705 INFO CG attempt 1/4 /coins/spx6900/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:46:07,918 INFO CG ok /coins/spx6900/market_chart status=200 dt=0.21s
# 2025-10-01 17:46:08,500 INFO CG attempt 1/4 /coins/curve-dao-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:46:08,714 INFO CG ok /coins/curve-dao-token/market_chart status=200 dt=0.21s
# 2025-10-01 17:46:09,312 INFO CG attempt 1/4 /coins/msol/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:46:09,331 WARNING CG 429 /coins/msol/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:47:09,940 INFO CG attempt 2/4 /coins/msol/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:47:10,175 INFO CG ok /coins/msol/market_chart status=200 dt=0.23s
# 2025-10-01 17:47:10,175 INFO prefetch 121/400 id=msol caps_pts=105 dt=61.46s
# 2025-10-01 17:47:10,631 INFO CG attempt 1/4 /coins/aerodrome-finance/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:47:10,824 INFO CG ok /coins/aerodrome-finance/market_chart status=200 dt=0.19s
# 2025-10-01 17:47:11,463 INFO CG attempt 1/4 /coins/arbitrum-bridged-wbtc-arbitrum-one/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:47:11,664 INFO CG ok /coins/arbitrum-bridged-wbtc-arbitrum-one/market_chart status=200 dt=0.20s
# 2025-10-01 17:47:12,181 INFO CG attempt 1/4 /coins/kaia/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:47:12,418 INFO CG ok /coins/kaia/market_chart status=200 dt=0.24s
# 2025-10-01 17:47:13,091 INFO CG attempt 1/4 /coins/pancakeswap-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:47:13,110 WARNING CG 429 /coins/pancakeswap-token/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:48:13,566 INFO CG attempt 2/4 /coins/pancakeswap-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:48:13,788 INFO CG ok /coins/pancakeswap-token/market_chart status=200 dt=0.22s
# 2025-10-01 17:48:13,788 INFO prefetch 125/400 id=pancakeswap-token caps_pts=105 dt=61.37s
# 2025-10-01 17:48:14,334 INFO CG attempt 1/4 /coins/the-graph/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:48:14,495 INFO CG ok /coins/the-graph/market_chart status=200 dt=0.16s
# 2025-10-01 17:48:15,091 INFO CG attempt 1/4 /coins/clbtc/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:48:15,116 WARNING CG 429 /coins/clbtc/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:49:15,776 INFO CG attempt 2/4 /coins/clbtc/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:49:15,938 INFO CG ok /coins/clbtc/market_chart status=200 dt=0.17s
# 2025-10-01 17:49:15,948 INFO prefetch 127/400 id=clbtc caps_pts=103 dt=61.45s
# 2025-10-01 17:49:16,588 INFO CG attempt 1/4 /coins/pyth-network/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:49:16,828 INFO CG ok /coins/pyth-network/market_chart status=200 dt=0.24s
# 2025-10-01 17:49:17,484 INFO CG attempt 1/4 /coins/fasttoken/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:49:17,719 INFO CG ok /coins/fasttoken/market_chart status=200 dt=0.23s
# 2025-10-01 17:49:18,303 INFO CG attempt 1/4 /coins/cgeth-hashkey-cloud/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:49:18,463 INFO CG ok /coins/cgeth-hashkey-cloud/market_chart status=200 dt=0.16s
# 2025-10-01 17:49:19,158 INFO CG attempt 1/4 /coins/floki/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:49:19,172 WARNING CG 429 /coins/floki/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:50:19,834 INFO CG attempt 2/4 /coins/floki/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:50:19,996 INFO CG ok /coins/floki/market_chart status=200 dt=0.16s
# 2025-10-01 17:50:19,998 INFO prefetch 131/400 id=floki caps_pts=105 dt=61.53s
# 2025-10-01 17:50:20,573 INFO CG attempt 1/4 /coins/pendle/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:50:20,778 INFO CG ok /coins/pendle/market_chart status=200 dt=0.20s
# 2025-10-01 17:50:21,378 INFO CG attempt 1/4 /coins/ripple-usd/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:50:21,398 WARNING CG 429 /coins/ripple-usd/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:51:21,953 INFO CG attempt 2/4 /coins/ripple-usd/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:51:22,185 INFO CG ok /coins/ripple-usd/market_chart status=200 dt=0.23s
# 2025-10-01 17:51:22,188 INFO prefetch 133/400 id=ripple-usd caps_pts=105 dt=61.41s
# 2025-10-01 17:51:22,655 INFO CG attempt 1/4 /coins/saros-finance/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:51:22,908 INFO CG ok /coins/saros-finance/market_chart status=200 dt=0.25s
# 2025-10-01 17:51:23,604 INFO CG attempt 1/4 /coins/conflux-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:51:23,829 INFO CG ok /coins/conflux-token/market_chart status=200 dt=0.22s
# 2025-10-01 17:51:24,509 INFO CG attempt 1/4 /coins/l2-standard-bridged-weth-base/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:51:24,722 INFO CG ok /coins/l2-standard-bridged-weth-base/market_chart status=200 dt=0.21s
# 2025-10-01 17:51:25,244 INFO CG attempt 1/4 /coins/raydium/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:51:25,261 WARNING CG 429 /coins/raydium/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:52:25,759 INFO CG attempt 2/4 /coins/raydium/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:52:25,966 INFO CG ok /coins/raydium/market_chart status=200 dt=0.21s
# 2025-10-01 17:52:25,967 INFO prefetch 137/400 id=raydium caps_pts=105 dt=61.24s
# 2025-10-01 17:52:26,419 INFO CG attempt 1/4 /coins/dogwifcoin/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:52:26,629 INFO CG ok /coins/dogwifcoin/market_chart status=200 dt=0.21s
# 2025-10-01 17:52:27,302 INFO CG attempt 1/4 /coins/ether-fi/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:52:27,518 INFO CG ok /coins/ether-fi/market_chart status=200 dt=0.22s
# 2025-10-01 17:52:28,139 INFO CG attempt 1/4 /coins/tbtc/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:52:28,154 WARNING CG 429 /coins/tbtc/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:53:28,750 INFO CG attempt 2/4 /coins/tbtc/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:53:29,353 INFO CG ok /coins/tbtc/market_chart status=200 dt=0.60s
# 2025-10-01 17:53:29,353 INFO prefetch 140/400 id=tbtc caps_pts=105 dt=61.83s
# 2025-10-01 17:53:30,044 INFO CG attempt 1/4 /coins/tezos/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:53:30,239 INFO CG ok /coins/tezos/market_chart status=200 dt=0.19s
# 2025-10-01 17:53:30,733 INFO CG attempt 1/4 /coins/ousg/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:53:30,951 INFO CG ok /coins/ousg/market_chart status=200 dt=0.22s
# 2025-10-01 17:53:31,423 INFO CG attempt 1/4 /coins/theta-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:53:31,670 INFO CG ok /coins/theta-token/market_chart status=200 dt=0.25s
# 2025-10-01 17:53:32,167 INFO CG attempt 1/4 /coins/global-dollar/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:53:32,189 WARNING CG 429 /coins/global-dollar/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:54:32,807 INFO CG attempt 2/4 /coins/global-dollar/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:54:33,052 INFO CG ok /coins/global-dollar/market_chart status=200 dt=0.24s
# 2025-10-01 17:54:33,052 INFO prefetch 144/400 id=global-dollar caps_pts=105 dt=61.38s
# 2025-10-01 17:54:33,515 INFO CG attempt 1/4 /coins/virtual-protocol/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:54:33,748 INFO CG ok /coins/virtual-protocol/market_chart status=200 dt=0.23s
# 2025-10-01 17:54:34,438 INFO CG attempt 1/4 /coins/iota/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:54:34,663 INFO CG ok /coins/iota/market_chart status=200 dt=0.22s
# 2025-10-01 17:54:35,197 INFO CG attempt 1/4 /coins/gala/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:54:35,214 WARNING CG 429 /coins/gala/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:55:35,899 INFO CG attempt 2/4 /coins/gala/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:55:36,117 INFO CG ok /coins/gala/market_chart status=200 dt=0.22s
# 2025-10-01 17:55:36,117 INFO prefetch 147/400 id=gala caps_pts=105 dt=61.46s
# 2025-10-01 17:55:36,676 INFO CG attempt 1/4 /coins/ethereum-name-service/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:55:36,891 INFO CG ok /coins/ethereum-name-service/market_chart status=200 dt=0.21s
# 2025-10-01 17:55:37,576 INFO CG attempt 1/4 /coins/atomone/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:55:37,786 INFO CG ok /coins/atomone/market_chart status=200 dt=0.21s
# 2025-10-01 17:55:38,439 INFO CG attempt 1/4 /coins/usdx-money-usdx/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:55:38,675 INFO CG ok /coins/usdx-money-usdx/market_chart status=200 dt=0.23s
# 2025-10-01 17:55:38,678 INFO prefetch 150/400 id=usdx-money-usdx caps_pts=105 dt=0.89s
# 2025-10-01 17:55:39,293 INFO CG attempt 1/4 /coins/ether-fi-staked-eth/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:55:39,311 WARNING CG 429 /coins/ether-fi-staked-eth/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:56:39,877 INFO CG attempt 2/4 /coins/ether-fi-staked-eth/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:56:40,087 INFO CG ok /coins/ether-fi-staked-eth/market_chart status=200 dt=0.21s
# 2025-10-01 17:56:40,091 INFO prefetch 151/400 id=ether-fi-staked-eth caps_pts=105 dt=61.41s
# 2025-10-01 17:56:40,563 INFO CG attempt 1/4 /coins/the-sandbox/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:56:40,747 INFO CG ok /coins/the-sandbox/market_chart status=200 dt=0.18s
# 2025-10-01 17:56:41,330 INFO CG attempt 1/4 /coins/ondo-us-dollar-yield/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:56:41,550 INFO CG ok /coins/ondo-us-dollar-yield/market_chart status=200 dt=0.22s
# 2025-10-01 17:56:42,089 INFO CG attempt 1/4 /coins/gteth/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:56:42,256 INFO CG ok /coins/gteth/market_chart status=200 dt=0.17s
# 2025-10-01 17:56:42,906 INFO CG attempt 1/4 /coins/stader-ethx/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:56:42,921 WARNING CG 429 /coins/stader-ethx/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:57:43,530 INFO CG attempt 2/4 /coins/stader-ethx/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:57:43,768 INFO CG ok /coins/stader-ethx/market_chart status=200 dt=0.24s
# 2025-10-01 17:57:43,768 INFO prefetch 155/400 id=stader-ethx caps_pts=105 dt=61.51s
# 2025-10-01 17:57:44,278 INFO CG attempt 1/4 /coins/newton-project/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:57:44,508 INFO CG ok /coins/newton-project/market_chart status=200 dt=0.22s
# 2025-10-01 17:57:45,062 INFO CG attempt 1/4 /coins/vaulta/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:57:45,276 INFO CG ok /coins/vaulta/market_chart status=200 dt=0.21s
# 2025-10-01 17:57:45,947 INFO CG attempt 1/4 /coins/fartcoin/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:57:46,136 INFO CG ok /coins/fartcoin/market_chart status=200 dt=0.19s
# 2025-10-01 17:57:46,651 INFO CG attempt 1/4 /coins/superstate-short-duration-us-government-securities-fund-ustb/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:57:46,669 WARNING CG 429 /coins/superstate-short-duration-us-government-securities-fund-ustb/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:58:47,354 INFO CG attempt 2/4 /coins/superstate-short-duration-us-government-securities-fund-ustb/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:58:47,582 INFO CG ok /coins/superstate-short-duration-us-government-securities-fund-ustb/market_chart status=200 dt=0.22s
# 2025-10-01 17:58:47,584 INFO prefetch 159/400 id=superstate-short-duration-us-government-securities-fund-ustb caps_pts=105 dt=61.45s
# 2025-10-01 17:58:48,097 INFO CG attempt 1/4 /coins/arbitrum-bridged-weth-arbitrum-one/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:58:48,349 INFO CG ok /coins/arbitrum-bridged-weth-arbitrum-one/market_chart status=200 dt=0.25s
# 2025-10-01 17:58:48,908 INFO CG attempt 1/4 /coins/aethir/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:58:49,241 INFO CG ok /coins/aethir/market_chart status=200 dt=0.33s
# 2025-10-01 17:58:49,902 INFO CG attempt 1/4 /coins/jasmycoin/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:58:50,129 INFO CG ok /coins/jasmycoin/market_chart status=200 dt=0.22s
# 2025-10-01 17:58:50,589 INFO CG attempt 1/4 /coins/jito-governance-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:58:50,607 WARNING CG 429 /coins/jito-governance-token/market_chart; sleeping 60.00s then retry
# 2025-10-01 17:59:51,300 INFO CG attempt 2/4 /coins/jito-governance-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:59:51,538 INFO CG ok /coins/jito-governance-token/market_chart status=200 dt=0.23s
# 2025-10-01 17:59:51,540 INFO prefetch 163/400 id=jito-governance-token caps_pts=105 dt=61.41s
# 2025-10-01 17:59:52,103 INFO CG attempt 1/4 /coins/binance-peg-dogecoin/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:59:52,283 INFO CG ok /coins/binance-peg-dogecoin/market_chart status=200 dt=0.18s
# 2025-10-01 17:59:52,859 INFO CG attempt 1/4 /coins/starknet/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:59:53,088 INFO CG ok /coins/starknet/market_chart status=200 dt=0.23s
# 2025-10-01 17:59:53,782 INFO CG attempt 1/4 /coins/swissborg/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:59:56,791 INFO CG ok /coins/swissborg/market_chart status=200 dt=3.01s
# 2025-10-01 17:59:57,470 INFO CG attempt 1/4 /coins/beldex/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:59:57,698 INFO CG ok /coins/beldex/market_chart status=200 dt=0.23s
# 2025-10-01 17:59:58,203 INFO CG attempt 1/4 /coins/mantle-restaked-eth/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 17:59:58,227 WARNING CG 429 /coins/mantle-restaked-eth/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:00:58,834 INFO CG attempt 2/4 /coins/mantle-restaked-eth/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:00:59,056 INFO CG ok /coins/mantle-restaked-eth/market_chart status=200 dt=0.22s
# 2025-10-01 18:00:59,056 INFO prefetch 168/400 id=mantle-restaked-eth caps_pts=105 dt=61.36s
# 2025-10-01 18:00:59,511 INFO CG attempt 1/4 /coins/morpho/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:00:59,743 INFO CG ok /coins/morpho/market_chart status=200 dt=0.23s
# 2025-10-01 18:01:00,409 INFO CG attempt 1/4 /coins/walrus-2/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:01:00,644 INFO CG ok /coins/walrus-2/market_chart status=200 dt=0.23s
# 2025-10-01 18:01:01,281 INFO CG attempt 1/4 /coins/bittorrent/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:01:01,509 INFO CG ok /coins/bittorrent/market_chart status=200 dt=0.23s
# 2025-10-01 18:01:02,208 INFO CG attempt 1/4 /coins/flow/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:01:02,382 INFO CG ok /coins/flow/market_chart status=200 dt=0.17s
# 2025-10-01 18:01:02,901 INFO CG attempt 1/4 /coins/decentraland/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:01:02,915 WARNING CG 429 /coins/decentraland/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:02:03,389 INFO CG attempt 2/4 /coins/decentraland/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:02:03,560 INFO CG ok /coins/decentraland/market_chart status=200 dt=0.17s
# 2025-10-01 18:02:03,561 INFO prefetch 173/400 id=decentraland caps_pts=105 dt=61.18s
# 2025-10-01 18:02:04,173 INFO CG attempt 1/4 /coins/sweth/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:02:04,423 INFO CG ok /coins/sweth/market_chart status=200 dt=0.25s
# 2025-10-01 18:02:05,092 INFO CG attempt 1/4 /coins/coinbase-wrapped-staked-eth/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:02:05,488 INFO CG ok /coins/coinbase-wrapped-staked-eth/market_chart status=200 dt=0.39s
# 2025-10-01 18:02:05,488 INFO prefetch 175/400 id=coinbase-wrapped-staked-eth caps_pts=105 dt=1.06s
# 2025-10-01 18:02:06,041 INFO CG attempt 1/4 /coins/zero-gravity/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:02:06,215 INFO CG ok /coins/zero-gravity/market_chart status=200 dt=0.17s
# 2025-10-01 18:02:06,785 INFO CG attempt 1/4 /coins/dexe/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:02:06,949 INFO CG ok /coins/dexe/market_chart status=200 dt=0.16s
# 2025-10-01 18:02:07,542 INFO CG attempt 1/4 /coins/eigenlayer/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:02:07,563 WARNING CG 429 /coins/eigenlayer/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:03:08,115 INFO CG attempt 2/4 /coins/eigenlayer/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:03:08,366 INFO CG ok /coins/eigenlayer/market_chart status=200 dt=0.25s
# 2025-10-01 18:03:08,366 INFO prefetch 178/400 id=eigenlayer caps_pts=105 dt=61.42s
# 2025-10-01 18:03:08,911 INFO CG attempt 1/4 /coins/usual-usd/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:03:09,166 INFO CG ok /coins/usual-usd/market_chart status=200 dt=0.25s
# 2025-10-01 18:03:09,630 INFO CG attempt 1/4 /coins/arbitrum-bridged-wrapped-eeth/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:03:09,812 INFO CG ok /coins/arbitrum-bridged-wrapped-eeth/market_chart status=200 dt=0.18s
# 2025-10-01 18:03:10,499 INFO CG attempt 1/4 /coins/bitcoin-avalanche-bridged-btc-b/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:03:10,756 INFO CG ok /coins/bitcoin-avalanche-bridged-btc-b/market_chart status=200 dt=0.26s
# 2025-10-01 18:03:11,249 INFO CG attempt 1/4 /coins/benqi-liquid-staked-avax/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:03:11,505 INFO CG ok /coins/benqi-liquid-staked-avax/market_chart status=200 dt=0.26s
# 2025-10-01 18:03:11,995 INFO CG attempt 1/4 /coins/trust-wallet-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:03:12,012 WARNING CG 429 /coins/trust-wallet-token/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:04:12,753 INFO CG attempt 2/4 /coins/trust-wallet-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:04:12,988 INFO CG ok /coins/trust-wallet-token/market_chart status=200 dt=0.23s
# 2025-10-01 18:04:12,989 INFO prefetch 183/400 id=trust-wallet-token caps_pts=105 dt=61.48s
# 2025-10-01 18:04:13,660 INFO CG attempt 1/4 /coins/usdai/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:04:13,678 WARNING CG 429 /coins/usdai/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:05:14,144 INFO CG attempt 2/4 /coins/usdai/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:05:14,369 INFO CG ok /coins/usdai/market_chart status=200 dt=0.22s
# 2025-10-01 18:05:14,371 INFO prefetch 184/400 id=usdai caps_pts=91 dt=61.38s
# 2025-10-01 18:05:14,912 INFO CG attempt 1/4 /coins/wormhole/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:05:15,169 INFO CG ok /coins/wormhole/market_chart status=200 dt=0.25s
# 2025-10-01 18:05:15,691 INFO CG attempt 1/4 /coins/mantle-bridged-usdt-mantle/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:05:15,985 INFO CG ok /coins/mantle-bridged-usdt-mantle/market_chart status=200 dt=0.29s
# 2025-10-01 18:05:16,516 INFO CG attempt 1/4 /coins/kinetiq-earn-vault/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:05:16,698 INFO CG ok /coins/kinetiq-earn-vault/market_chart status=200 dt=0.18s
# 2025-10-01 18:05:17,347 INFO CG attempt 1/4 /coins/bitcoin-cash-sv/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:05:17,572 INFO CG ok /coins/bitcoin-cash-sv/market_chart status=200 dt=0.22s
# 2025-10-01 18:05:18,196 INFO CG attempt 1/4 /coins/true-usd/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:05:18,220 WARNING CG 429 /coins/true-usd/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:06:18,818 INFO CG attempt 2/4 /coins/true-usd/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:06:19,071 INFO CG ok /coins/true-usd/market_chart status=200 dt=0.25s
# 2025-10-01 18:06:19,071 INFO prefetch 189/400 id=true-usd caps_pts=105 dt=61.50s
# 2025-10-01 18:06:19,529 INFO CG attempt 1/4 /coins/loaded-lions/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:06:19,544 WARNING CG 429 /coins/loaded-lions/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:07:20,034 INFO CG attempt 2/4 /coins/loaded-lions/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:07:20,263 INFO CG ok /coins/loaded-lions/market_chart status=200 dt=0.23s
# 2025-10-01 18:07:20,264 INFO prefetch 190/400 id=loaded-lions caps_pts=105 dt=61.19s
# 2025-10-01 18:07:20,947 INFO CG attempt 1/4 /coins/sun-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:07:21,158 INFO CG ok /coins/sun-token/market_chart status=200 dt=0.21s
# 2025-10-01 18:07:21,677 INFO CG attempt 1/4 /coins/wrapped-avax/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:07:21,911 INFO CG ok /coins/wrapped-avax/market_chart status=200 dt=0.23s
# 2025-10-01 18:07:22,375 INFO CG attempt 1/4 /coins/falcon-finance-ff/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:07:22,539 INFO CG ok /coins/falcon-finance-ff/market_chart status=200 dt=0.16s
# 2025-10-01 18:07:23,143 INFO CG attempt 1/4 /coins/polygon-pos-bridged-weth-polygon-pos/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:07:23,370 INFO CG ok /coins/polygon-pos-bridged-weth-polygon-pos/market_chart status=200 dt=0.22s
# 2025-10-01 18:07:23,918 INFO CG attempt 1/4 /coins/helium/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:07:23,934 WARNING CG 429 /coins/helium/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:08:24,453 INFO CG attempt 2/4 /coins/helium/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:08:24,671 INFO CG ok /coins/helium/market_chart status=200 dt=0.22s
# 2025-10-01 18:08:24,672 INFO prefetch 195/400 id=helium caps_pts=105 dt=61.30s
# 2025-10-01 18:08:25,132 INFO CG attempt 1/4 /coins/bybit-staked-sol/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:08:25,369 INFO CG ok /coins/bybit-staked-sol/market_chart status=200 dt=0.24s
# 2025-10-01 18:08:25,861 INFO CG attempt 1/4 /coins/frax-ether/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:08:25,876 WARNING CG 429 /coins/frax-ether/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:09:26,466 INFO CG attempt 2/4 /coins/frax-ether/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:09:26,684 INFO CG ok /coins/frax-ether/market_chart status=200 dt=0.21s
# 2025-10-01 18:09:26,687 INFO prefetch 197/400 id=frax-ether caps_pts=105 dt=61.32s
# 2025-10-01 18:09:27,385 INFO CG attempt 1/4 /coins/dydx-chain/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:09:27,703 INFO CG ok /coins/dydx-chain/market_chart status=200 dt=0.32s
# 2025-10-01 18:09:28,286 INFO CG attempt 1/4 /coins/instadapp/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:09:28,688 INFO CG ok /coins/instadapp/market_chart status=200 dt=0.40s
# 2025-10-01 18:09:29,388 INFO CG attempt 1/4 /coins/usdd/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:09:29,634 INFO CG ok /coins/usdd/market_chart status=200 dt=0.24s
# 2025-10-01 18:09:29,634 INFO prefetch 200/400 id=usdd caps_pts=105 dt=0.95s
# 2025-10-01 18:09:30,289 INFO CG attempt 1/4 /coins/ethena-staked-ena/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:09:30,304 WARNING CG 429 /coins/ethena-staked-ena/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:10:30,926 INFO CG attempt 2/4 /coins/ethena-staked-ena/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:10:31,095 INFO CG ok /coins/ethena-staked-ena/market_chart status=200 dt=0.17s
# 2025-10-01 18:10:31,096 INFO prefetch 201/400 id=ethena-staked-ena caps_pts=105 dt=61.46s
# 2025-10-01 18:10:31,699 INFO CG attempt 1/4 /coins/polygon-pos-bridged-dai-polygon-pos/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:10:31,925 INFO CG ok /coins/polygon-pos-bridged-dai-polygon-pos/market_chart status=200 dt=0.22s
# 2025-10-01 18:10:32,442 INFO CG attempt 1/4 /coins/solmev/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:10:32,617 INFO CG ok /coins/solmev/market_chart status=200 dt=0.17s
# 2025-10-01 18:10:33,141 INFO CG attempt 1/4 /coins/syrup/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:10:33,154 WARNING CG 429 /coins/syrup/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:11:33,676 INFO CG attempt 2/4 /coins/syrup/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:11:33,871 INFO CG ok /coins/syrup/market_chart status=200 dt=0.19s
# 2025-10-01 18:11:33,872 INFO prefetch 204/400 id=syrup caps_pts=105 dt=61.26s
# 2025-10-01 18:11:34,408 INFO CG attempt 1/4 /coins/vision-3/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:11:34,612 INFO CG ok /coins/vision-3/market_chart status=200 dt=0.20s
# 2025-10-01 18:11:35,237 INFO CG attempt 1/4 /coins/chiliz/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:11:35,433 INFO CG ok /coins/chiliz/market_chart status=200 dt=0.19s
# 2025-10-01 18:11:35,924 INFO CG attempt 1/4 /coins/apecoin/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:11:36,145 INFO CG ok /coins/apecoin/market_chart status=200 dt=0.22s
# 2025-10-01 18:11:36,701 INFO CG attempt 1/4 /coins/bridged-usdc-polygon-pos-bridge/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:11:36,717 WARNING CG 429 /coins/bridged-usdc-polygon-pos-bridge/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:12:37,298 INFO CG attempt 2/4 /coins/bridged-usdc-polygon-pos-bridge/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:12:37,538 INFO CG ok /coins/bridged-usdc-polygon-pos-bridge/market_chart status=200 dt=0.24s
# 2025-10-01 18:12:37,539 INFO prefetch 208/400 id=bridged-usdc-polygon-pos-bridge caps_pts=105 dt=61.39s
# 2025-10-01 18:12:38,178 INFO CG attempt 1/4 /coins/steakhouse-usdc-morpho-vault/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:12:38,394 INFO CG ok /coins/steakhouse-usdc-morpho-vault/market_chart status=200 dt=0.21s
# 2025-10-01 18:12:38,922 INFO CG attempt 1/4 /coins/based-brett/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:12:39,139 INFO CG ok /coins/based-brett/market_chart status=200 dt=0.22s
# 2025-10-01 18:12:39,747 INFO CG attempt 1/4 /coins/beam-2/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:12:39,972 INFO CG ok /coins/beam-2/market_chart status=200 dt=0.22s
# 2025-10-01 18:12:40,563 INFO CG attempt 1/4 /coins/apenft/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:12:40,577 WARNING CG 429 /coins/apenft/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:13:41,070 INFO CG attempt 2/4 /coins/apenft/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:13:41,423 INFO CG ok /coins/apenft/market_chart status=200 dt=0.35s
# 2025-10-01 18:13:41,423 INFO prefetch 212/400 id=apenft caps_pts=105 dt=61.45s
# 2025-10-01 18:13:42,065 INFO CG attempt 1/4 /coins/neo/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:13:42,271 INFO CG ok /coins/neo/market_chart status=200 dt=0.20s
# 2025-10-01 18:13:42,926 INFO CG attempt 1/4 /coins/thorchain/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:13:43,218 INFO CG ok /coins/thorchain/market_chart status=200 dt=0.29s
# 2025-10-01 18:13:43,904 INFO CG attempt 1/4 /coins/linea/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:13:44,085 INFO CG ok /coins/linea/market_chart status=200 dt=0.18s
# 2025-10-01 18:13:44,583 INFO CG attempt 1/4 /coins/hashnote-usyc/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:13:44,601 WARNING CG 429 /coins/hashnote-usyc/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:14:45,179 INFO CG attempt 2/4 /coins/hashnote-usyc/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:14:45,423 INFO CG ok /coins/hashnote-usyc/market_chart status=200 dt=0.24s
# 2025-10-01 18:14:45,424 INFO prefetch 216/400 id=hashnote-usyc caps_pts=99 dt=61.34s
# 2025-10-01 18:14:46,119 INFO CG attempt 1/4 /coins/compound-governance-token/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:14:46,353 INFO CG ok /coins/compound-governance-token/market_chart status=200 dt=0.23s
# 2025-10-01 18:14:46,873 INFO CG attempt 1/4 /coins/wrapped-hype/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:14:47,102 INFO CG ok /coins/wrapped-hype/market_chart status=200 dt=0.23s
# 2025-10-01 18:14:47,677 INFO CG attempt 1/4 /coins/usdb/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:14:47,921 INFO CG ok /coins/usdb/market_chart status=200 dt=0.24s
# 2025-10-01 18:14:48,422 INFO CG attempt 1/4 /coins/four/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:14:48,444 WARNING CG 429 /coins/four/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:15:49,077 INFO CG attempt 2/4 /coins/four/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:15:49,242 INFO CG ok /coins/four/market_chart status=200 dt=0.16s
# 2025-10-01 18:15:49,243 INFO prefetch 220/400 id=four caps_pts=105 dt=61.32s
# 2025-10-01 18:15:49,704 INFO CG attempt 1/4 /coins/gnosis/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:15:49,892 INFO CG ok /coins/gnosis/market_chart status=200 dt=0.19s
# 2025-10-01 18:15:50,439 INFO CG attempt 1/4 /coins/coredaoorg/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:15:50,685 INFO CG ok /coins/coredaoorg/market_chart status=200 dt=0.24s
# 2025-10-01 18:15:51,345 INFO CG attempt 1/4 /coins/reserve-protocol-eth-plus/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:15:51,576 INFO CG ok /coins/reserve-protocol-eth-plus/market_chart status=200 dt=0.23s
# 2025-10-01 18:15:52,188 INFO CG attempt 1/4 /coins/zksync/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:15:52,205 WARNING CG 429 /coins/zksync/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:16:52,725 INFO CG attempt 2/4 /coins/zksync/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:16:52,960 INFO CG ok /coins/zksync/market_chart status=200 dt=0.23s
# 2025-10-01 18:16:52,961 INFO prefetch 224/400 id=zksync caps_pts=105 dt=61.38s
# 2025-10-01 18:16:53,513 INFO CG attempt 1/4 /coins/savings-dai/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:16:53,743 INFO CG ok /coins/savings-dai/market_chart status=200 dt=0.23s
# 2025-10-01 18:16:53,744 INFO prefetch 225/400 id=savings-dai caps_pts=105 dt=0.78s
# 2025-10-01 18:16:54,286 INFO CG attempt 1/4 /coins/elrond-erd-2/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:16:54,487 INFO CG ok /coins/elrond-erd-2/market_chart status=200 dt=0.20s
# 2025-10-01 18:16:54,958 INFO CG attempt 1/4 /coins/treehouse-eth/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:16:55,176 INFO CG ok /coins/treehouse-eth/market_chart status=200 dt=0.22s
# 2025-10-01 18:16:55,680 INFO CG attempt 1/4 /coins/havven/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:16:55,835 INFO CG ok /coins/havven/market_chart status=200 dt=0.16s
# 2025-10-01 18:16:56,535 INFO CG attempt 1/4 /coins/unit-bitcoin/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:16:56,550 WARNING CG 429 /coins/unit-bitcoin/market_chart; sleeping 60.00s then retry
# 2025-10-01 18:17:57,108 INFO CG attempt 2/4 /coins/unit-bitcoin/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:17:57,322 INFO CG ok /coins/unit-bitcoin/market_chart status=200 dt=0.21s
# 2025-10-01 18:17:57,322 INFO prefetch 229/400 id=unit-bitcoin caps_pts=105 dt=61.48s
# 2025-10-01 18:17:57,793 INFO CG attempt 1/4 /coins/arweave/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:17:57,997 INFO CG ok /coins/arweave/market_chart status=200 dt=0.20s
# 2025-10-01 18:17:58,551 INFO CG attempt 1/4 /coins/telcoin/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:17:58,786 INFO CG ok /coins/telcoin/market_chart status=200 dt=0.23s
# 2025-10-01 18:17:59,264 INFO CG attempt 1/4 /coins/superfarm/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:17:59,463 INFO CG ok /coins/superfarm/market_chart status=200 dt=0.20s
# 2025-10-01 18:18:00,141 INFO CG attempt 1/4 /coins/chain-2/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:18:00,358 INFO CG ok /coins/chain-2/market_chart status=200 dt=0.21s
# 2025-10-01 18:18:00,875 INFO CG attempt 1/4 /coins/astherus-staked-bnb/market_chart params={'vs_currency': 'usd', 'days': 104, 'interval': 'daily'}
# 2025-10-01 18:18:00,895 WARNING CG 429 /coins/astherus-staked-bnb/market_chart; sleeping 60.00s then retry
